# %%
using Grid

# %%
using PyPlot

# %%
f(x)=x^3
# Out:
# f (generic function with 1 method)

# %%
n=100
grid=Array(Float64,n)
vals=Array(Float64,n)
for i in 1:n
    grid[i]=i
    vals[i]=f(i)
end
function func(x)
    function k(x)
        return searchsortedlast(grid,x)
    end
    return (vals[k(x)+1]-vals[k(x)])/(grid[k(x)+1]-grid[k(x)])*(x-grid[k(x)])+vals[k(x)]
end
# Out:
# func (generic function with 1 method)

# %%
func(7.5)
# Out:
# 427.5

# %%
plot(grid,vals)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000011CE2B0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x000000001008E7F0>
