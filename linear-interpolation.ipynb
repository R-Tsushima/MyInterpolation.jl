# %%
using PyPlot
include("lin_int.jl")
# Out:
# lin_int (generic function with 1 method)

# %%
g(x)=x^3
# Out:
# g (generic function with 1 method)

# %%
n=100
grid=Array(Float64,n)
vals=Array(Float64,n)
for i in 1:n
    grid[i]=i
    vals[i]=g(i)
end

# %%
f=lin_int(grid,vals)
# Out:
# func (generic function with 1 method)

# %%
f(2.5)
# Out:
# 17.5

# %%
using PyPlot
fgrid = linspace(1,99, 5)
plot(grid,vals)
plot(fgrid, [f(x) for x in fgrid])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000001011E2B0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x000000001B674A20>
